# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %% [markdown]
# ### Create a new set of 2,000 random latitudes and longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get the nearest city using the citipy module

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %% [markdown]
# ### Perform an API call with the OpenWeatherMap

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a294f8e259de58017d6489f0b4d2b844

# %% [markdown]
# ### Retrieve the following information from the API call:
# #### Latitude and longitude
# #### Maximum temperature
# #### Percent humidity
# #### Percent cloudiness
# #### Wind speed
# #### Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | san quintin
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | metro
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | nguruka
# Processing Record 13 of Set 1 | drayton valley
# Processing Record 14 of Set 1 | wanganui
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | ostrovnoy
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | hearst
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | koboko
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | lata
# Processing Record 27 of Set 1 | conde
# Processing Record 28 of Set 1 | praia da vitoria
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | port blair
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | luanda
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | asbury park
# Processing Record 36 of Set 1 | lagunas
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | flinders
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | saint-paul
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | padang
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | kuytun
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | at-bashi
# Processing Record 2 of Set 2 | yurimaguas
# Processing Record 3 of Set 2 | bandarbeyla
# Processing Record 4 of Set 2 | dakar
# Processing Record 5 of Set 2 | beausejour
# Processing Record 6 of Set 2 | constitucion
# Processing Record 7 of Set 2 | san cristobal
# Processing Record 8 of Set 2 | sayyan
# Processing Record 9 of Set 2 | san lawrenz
# Processing Record 10 of Set 2 | santander
# Processing Record 11 of Set 2 | isangel
# Processing Record 12 of Set 2 | glinka
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | rayong
# Processing Record 15 of Set 2 | kavaratti
# Processing Record 16 of Set 2 | vredendal
# Processing Record 17 of Set 2 | touros
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | santa isabel do rio negro
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | namatanai
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | fereydun kenar
# Processing Record 25 of Set 2 | zaltan
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | stephenville
# Processing Record 28 of Set 2 | la rioja
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | rikitea
# Processing Record 35 of Set 2 | akdepe
# Processing Record 36 of Set 2 | lima
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | syracuse
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | jumla
# Processing Record 41 of Set 2 | saint-pierre
# Processing Record 42 of Set 2 | tabukiniberu
# City not found. Skipping...
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | blackfoot
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | elizabeth city
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | lucapa
# Processing Record 49 of Set 2 | tsiroanomandidy
# Processing Record 50 of Set 2 | camacupa
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | biak
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | santa maria
# Processing Record 6 of Set 3 | sovetskiy
# Processing Record 7 of Set 3 | santa helena de goias
# Processing Record 8 of Set 3 | chara
# Processing Record 9 of Set 3 | hasaki
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 3 | kalmunai
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | nhamunda
# Processing Record 16 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | timbo
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | manado
# Processing Record 27 of Set 3 | pingliang
# Processing Record 28 of Set 3 | fairbanks
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | abakaliki
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | mecca
# Processing Record 33 of Set 3 | luganville
# Processing Record 34 of Set 3 | aromashevo
# Processing Record 35 of Set 3 | farkhor
# Processing Record 36 of Set 3 | simao
# Processing Record 37 of Set 3 | mangai
# Processing Record 38 of Set 3 | srednekolymsk
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | abu samrah
# Processing Record 41 of Set 3 | maloarkhangelsk
# Processing Record 42 of Set 3 | gold coast
# Processing Record 43 of Set 3 | hambantota
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | geraldton
# Processing Record 46 of Set 3 | severo-kurilsk
# Processing Record 47 of Set 3 | grand-santi
# Processing Record 48 of Set 3 | banda aceh
# Processing Record 49 of Set 3 | talcahuano
# Processing Record 50 of Set 3 | mormugao
# Processing Record 1 of Set 4 | xuddur
# Processing Record 2 of Set 4 | grand gaube
# Processing Record 3 of Set 4 | camacha
# Processing Record 4 of Set 4 | qui nhon
# Processing Record 5 of Set 4 | platteville
# Processing Record 6 of Set 4 | antipino
# Processing Record 7 of Set 4 | novoseleznevo
# Processing Record 8 of Set 4 | davila
# Processing Record 9 of Set 4 | kaduna
# Processing Record 10 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | mutis
# Processing Record 14 of Set 4 | haines junction
# Processing Record 15 of Set 4 | sinnamary
# Processing Record 16 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 4 | abbeville
# Processing Record 18 of Set 4 | mandera
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | thunder bay
# Processing Record 21 of Set 4 | antofagasta
# Processing Record 22 of Set 4 | bac lieu
# Processing Record 23 of Set 4 | galle
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | yumen
# Processing Record 26 of Set 4 | taoudenni
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | seoul
# Processing Record 29 of Set 4 | dingle
# Processing Record 30 of Set 4 | priladozhskiy
# Processing Record 31 of Set 4 | harper
# Processing Record 32 of Set 4 | nabire
# Processing Record 33 of Set 4 | meadow lake
# Processing Record 34 of Set 4 | estepa
# Processing Record 35 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 4 | miquelon
# Processing Record 37 of Set 4 | niquelandia
# Processing Record 38 of Set 4 | tahta
# Processing Record 39 of Set 4 | ndele
# Processing Record 40 of Set 4 | butaritari
# Processing Record 41 of Set 4 | songjianghe
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | garowe
# Processing Record 44 of Set 4 | gigmoto
# Processing Record 45 of Set 4 | quatre cocos
# Processing Record 46 of Set 4 | teknaf
# Processing Record 47 of Set 4 | pevek
# Processing Record 48 of Set 4 | albania
# Processing Record 49 of Set 4 | talnakh
# Processing Record 50 of Set 4 | ardassa
# Processing Record 1 of Set 5 | alofi
# Processing Record 2 of Set 5 | makakilo city
# Processing Record 3 of Set 5 | svetlogorsk
# Processing Record 4 of Set 5 | kloulklubed
# Processing Record 5 of Set 5 | toronto
# Processing Record 6 of Set 5 | gazojak
# Processing Record 7 of Set 5 | shediac
# Processing Record 8 of Set 5 | mikuni
# Processing Record 9 of Set 5 | khandyga
# Processing Record 10 of Set 5 | umm lajj
# Processing Record 11 of Set 5 | costinesti
# Processing Record 12 of Set 5 | tromso
# Processing Record 13 of Set 5 | narsaq
# Processing Record 14 of Set 5 | rocha
# Processing Record 15 of Set 5 | virginia beach
# Processing Record 16 of Set 5 | tarakeswar
# Processing Record 17 of Set 5 | warrington
# Processing Record 18 of Set 5 | neftcala
# Processing Record 19 of Set 5 | tacna
# Processing Record 20 of Set 5 | kahului
# Processing Record 21 of Set 5 | tecpan
# Processing Record 22 of Set 5 | tarifa
# Processing Record 23 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 5 | sitka
# Processing Record 25 of Set 5 | belyy yar
# Processing Record 26 of Set 5 | moranbah
# Processing Record 27 of Set 5 | agadez
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | epe
# Processing Record 30 of Set 5 | mokhotlong
# Processing Record 31 of Set 5 | ishim
# Processing Record 32 of Set 5 | severo-yeniseyskiy
# Processing Record 33 of Set 5 | nikolskoye
# Processing Record 34 of Set 5 | carnarvon
# Processing Record 35 of Set 5 | torbay
# Processing Record 36 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 5 | almenara
# Processing Record 38 of Set 5 | laguna
# Processing Record 39 of Set 5 | teguise
# Processing Record 40 of Set 5 | haverfordwest
# Processing Record 41 of Set 5 | lazaro cardenas
# Processing Record 42 of Set 5 | ambanja
# Processing Record 43 of Set 5 | valparaiso
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | bontang
# Processing Record 46 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 5 | bambous virieux
# Processing Record 48 of Set 5 | glace bay
# Processing Record 49 of Set 5 | te anau
# Processing Record 50 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 6 | sokoto
# Processing Record 2 of Set 6 | los llanos de aridane
# Processing Record 3 of Set 6 | lagoa
# Processing Record 4 of Set 6 | deputatskiy
# Processing Record 5 of Set 6 | upington
# Processing Record 6 of Set 6 | mayya
# Processing Record 7 of Set 6 | itarema
# Processing Record 8 of Set 6 | zhangye
# Processing Record 9 of Set 6 | tabou
# Processing Record 10 of Set 6 | saint-augustin
# Processing Record 11 of Set 6 | alexandria
# Processing Record 12 of Set 6 | pampa
# Processing Record 13 of Set 6 | jawhar
# Processing Record 14 of Set 6 | mansa
# Processing Record 15 of Set 6 | eregli
# Processing Record 16 of Set 6 | caravelas
# Processing Record 17 of Set 6 | puerto narino
# Processing Record 18 of Set 6 | ardabil
# Processing Record 19 of Set 6 | behshahr
# Processing Record 20 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | tuatapere
# Processing Record 23 of Set 6 | kapit
# Processing Record 24 of Set 6 | doha
# Processing Record 25 of Set 6 | birao
# Processing Record 26 of Set 6 | balykshi
# Processing Record 27 of Set 6 | parrita
# Processing Record 28 of Set 6 | portland
# Processing Record 29 of Set 6 | alibag
# Processing Record 30 of Set 6 | castro
# Processing Record 31 of Set 6 | erenhot
# Processing Record 32 of Set 6 | banjarmasin
# Processing Record 33 of Set 6 | aksarka
# Processing Record 34 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 6 | finschhafen
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | soto la marina
# Processing Record 38 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 6 | blackwater
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | baykit
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | bonthe
# Processing Record 45 of Set 6 | denau
# City not found. Skipping...
# Processing Record 46 of Set 6 | praia
# Processing Record 47 of Set 6 | martapura
# Processing Record 48 of Set 6 | arroyo
# Processing Record 49 of Set 6 | georgiyevka
# Processing Record 50 of Set 6 | kismayo
# Processing Record 1 of Set 7 | saldanha
# Processing Record 2 of Set 7 | aklavik
# Processing Record 3 of Set 7 | conceicao do araguaia
# Processing Record 4 of Set 7 | puerto escondido
# Processing Record 5 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 6 of Set 7 | ancud
# Processing Record 7 of Set 7 | vestmannaeyjar
# Processing Record 8 of Set 7 | nalgonda
# Processing Record 9 of Set 7 | gambela
# Processing Record 10 of Set 7 | barcelos
# Processing Record 11 of Set 7 | iracoubo
# Processing Record 12 of Set 7 | dunedin
# Processing Record 13 of Set 7 | tawang
# Processing Record 14 of Set 7 | gunjur
# Processing Record 15 of Set 7 | tiarei
# Processing Record 16 of Set 7 | edgewater
# Processing Record 17 of Set 7 | leningradskiy
# Processing Record 18 of Set 7 | jiuquan
# Processing Record 19 of Set 7 | smithers
# Processing Record 20 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 7 | hurghada
# Processing Record 22 of Set 7 | xinzhou
# Processing Record 23 of Set 7 | great falls
# Processing Record 24 of Set 7 | tyukhtet
# Processing Record 25 of Set 7 | vologda
# Processing Record 26 of Set 7 | mao
# Processing Record 27 of Set 7 | camacari
# Processing Record 28 of Set 7 | copiapo
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 31 of Set 7 | port lincoln
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | long beach
# Processing Record 35 of Set 7 | chato
# Processing Record 36 of Set 7 | sioux lookout
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 7 | iisalmi
# Processing Record 40 of Set 7 | tawzar
# City not found. Skipping...
# Processing Record 41 of Set 7 | acajutla
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | bonavista
# Processing Record 44 of Set 7 | dombarovskiy
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | arsk
# Processing Record 47 of Set 7 | asau
# Processing Record 48 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 49 of Set 7 | krasnyy chikoy
# Processing Record 50 of Set 7 | tari
# Processing Record 1 of Set 8 | linxia
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | erzin
# Processing Record 4 of Set 8 | omboue
# Processing Record 5 of Set 8 | labuan
# Processing Record 6 of Set 8 | yulara
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | qurayyat
# Processing Record 9 of Set 8 | victor harbor
# Processing Record 10 of Set 8 | fermoy
# Processing Record 11 of Set 8 | bereda
# Processing Record 12 of Set 8 | sol-iletsk
# Processing Record 13 of Set 8 | lodja
# Processing Record 14 of Set 8 | mount gambier
# Processing Record 15 of Set 8 | strezhevoy
# Processing Record 16 of Set 8 | zeya
# Processing Record 17 of Set 8 | gondanglegi
# Processing Record 18 of Set 8 | verkhoyansk
# Processing Record 19 of Set 8 | maua
# Processing Record 20 of Set 8 | ust-kuyga
# Processing Record 21 of Set 8 | kenai
# Processing Record 22 of Set 8 | novyy urgal
# Processing Record 23 of Set 8 | landau
# Processing Record 24 of Set 8 | inhambane
# Processing Record 25 of Set 8 | charters towers
# Processing Record 26 of Set 8 | malpe
# Processing Record 27 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 8 | dwarka
# Processing Record 29 of Set 8 | bartlesville
# Processing Record 30 of Set 8 | port hardy
# Processing Record 31 of Set 8 | roald
# Processing Record 32 of Set 8 | gat
# Processing Record 33 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 8 | berbera
# Processing Record 36 of Set 8 | guasdualito
# Processing Record 37 of Set 8 | nebbi
# Processing Record 38 of Set 8 | rincon
# Processing Record 39 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 8 | nishihara
# Processing Record 41 of Set 8 | kysyl-syr
# Processing Record 42 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | jati
# Processing Record 46 of Set 8 | mount isa
# Processing Record 47 of Set 8 | kodiak
# Processing Record 48 of Set 8 | naze
# Processing Record 49 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 8 | lamont
# Processing Record 1 of Set 9 | arlit
# Processing Record 2 of Set 9 | sakakah
# Processing Record 3 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 9 | coquimbo
# Processing Record 6 of Set 9 | miri
# Processing Record 7 of Set 9 | barra patuca
# Processing Record 8 of Set 9 | nanga eboko
# Processing Record 9 of Set 9 | hualmay
# Processing Record 10 of Set 9 | diego de almagro
# Processing Record 11 of Set 9 | richards bay
# Processing Record 12 of Set 9 | san patricio
# Processing Record 13 of Set 9 | san vicente
# Processing Record 14 of Set 9 | linfen
# Processing Record 15 of Set 9 | nome
# Processing Record 16 of Set 9 | linqiong
# Processing Record 17 of Set 9 | antalaha
# Processing Record 18 of Set 9 | celina
# Processing Record 19 of Set 9 | cobija
# Processing Record 20 of Set 9 | sobolevo
# Processing Record 21 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 22 of Set 9 | prior lake
# Processing Record 23 of Set 9 | pyay
# Processing Record 24 of Set 9 | atasu
# Processing Record 25 of Set 9 | bogale
# Processing Record 26 of Set 9 | lagos
# Processing Record 27 of Set 9 | upernavik
# Processing Record 28 of Set 9 | northam
# Processing Record 29 of Set 9 | milkovo
# Processing Record 30 of Set 9 | siwan
# Processing Record 31 of Set 9 | lorengau
# Processing Record 32 of Set 9 | thinadhoo
# Processing Record 33 of Set 9 | ugoofaaru
# Processing Record 34 of Set 9 | whitehorse
# Processing Record 35 of Set 9 | saint george
# Processing Record 36 of Set 9 | vao
# Processing Record 37 of Set 9 | bathsheba
# Processing Record 38 of Set 9 | ayr
# Processing Record 39 of Set 9 | akureyri
# Processing Record 40 of Set 9 | pinega
# Processing Record 41 of Set 9 | carutapera
# Processing Record 42 of Set 9 | rawlins
# Processing Record 43 of Set 9 | cockburn town
# Processing Record 44 of Set 9 | tual
# Processing Record 45 of Set 9 | balabac
# Processing Record 46 of Set 9 | coihaique
# Processing Record 47 of Set 9 | oranjestad
# Processing Record 48 of Set 9 | jinchang
# Processing Record 49 of Set 9 | katsuura
# Processing Record 50 of Set 9 | ostersund
# Processing Record 1 of Set 10 | miles city
# Processing Record 2 of Set 10 | nuuk
# Processing Record 3 of Set 10 | kaitong
# Processing Record 4 of Set 10 | jiblah
# Processing Record 5 of Set 10 | rio grande
# Processing Record 6 of Set 10 | ulagan
# Processing Record 7 of Set 10 | oistins
# Processing Record 8 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 10 | mumford
# Processing Record 10 of Set 10 | samarai
# Processing Record 11 of Set 10 | may pen
# Processing Record 12 of Set 10 | ponta delgada
# Processing Record 13 of Set 10 | palmer
# Processing Record 14 of Set 10 | hokitika
# Processing Record 15 of Set 10 | kushima
# Processing Record 16 of Set 10 | springbok
# Processing Record 17 of Set 10 | salalah
# Processing Record 18 of Set 10 | zlobin
# Processing Record 19 of Set 10 | iquique
# Processing Record 20 of Set 10 | puerto quijarro
# Processing Record 21 of Set 10 | fare
# Processing Record 22 of Set 10 | odweyne
# Processing Record 23 of Set 10 | yerbogachen
# Processing Record 24 of Set 10 | changji
# Processing Record 25 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 10 | karlstad
# Processing Record 27 of Set 10 | andreapol
# Processing Record 28 of Set 10 | amapa
# Processing Record 29 of Set 10 | moba
# Processing Record 30 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 10 | la ronge
# Processing Record 32 of Set 10 | lethem
# Processing Record 33 of Set 10 | muros
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | nuevitas
# Processing Record 36 of Set 10 | tilichiki
# Processing Record 37 of Set 10 | santa flavia
# Processing Record 38 of Set 10 | winsum
# Processing Record 39 of Set 10 | raudeberg
# Processing Record 40 of Set 10 | safranbolu
# Processing Record 41 of Set 10 | dimona
# Processing Record 42 of Set 10 | parkersburg
# Processing Record 43 of Set 10 | quelimane
# Processing Record 44 of Set 10 | cody
# Processing Record 45 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | lyantonde
# Processing Record 47 of Set 10 | port hedland
# Processing Record 48 of Set 10 | zaprudnya
# Processing Record 49 of Set 10 | honiara
# Processing Record 50 of Set 10 | smidovich
# Processing Record 1 of Set 11 | jizan
# Processing Record 2 of Set 11 | melville
# Processing Record 3 of Set 11 | batemans bay
# Processing Record 4 of Set 11 | codrington
# Processing Record 5 of Set 11 | lakki marwat
# Processing Record 6 of Set 11 | malakal
# Processing Record 7 of Set 11 | bani
# Processing Record 8 of Set 11 | eureka
# Processing Record 9 of Set 11 | faya
# Processing Record 10 of Set 11 | pangnirtung
# Processing Record 11 of Set 11 | pulandian
# Processing Record 12 of Set 11 | opuwo
# Processing Record 13 of Set 11 | roma
# Processing Record 14 of Set 11 | hami
# Processing Record 15 of Set 11 | alice springs
# Processing Record 16 of Set 11 | kemijarvi
# Processing Record 17 of Set 11 | ahipara
# Processing Record 18 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 11 | north bend
# Processing Record 20 of Set 11 | xihe
# Processing Record 21 of Set 11 | udachnyy
# Processing Record 22 of Set 11 | payakumbuh
# Processing Record 23 of Set 11 | marsh harbour
# Processing Record 24 of Set 11 | adrar
# Processing Record 25 of Set 11 | rapid city
# Processing Record 26 of Set 11 | hirtshals
# Processing Record 27 of Set 11 | krasnoselkup
# Processing Record 28 of Set 11 | marabba
# Processing Record 29 of Set 11 | sur
# Processing Record 30 of Set 11 | grindavik
# Processing Record 31 of Set 11 | trincomalee
# Processing Record 32 of Set 11 | brisbane
# Processing Record 33 of Set 11 | cognac
# Processing Record 34 of Set 11 | kavieng
# Processing Record 35 of Set 11 | husavik
# Processing Record 36 of Set 11 | anchorage
# Processing Record 37 of Set 11 | hailey
# Processing Record 38 of Set 11 | buraydah
# Processing Record 39 of Set 11 | merauke
# Processing Record 40 of Set 11 | lavrentiya
# Processing Record 41 of Set 11 | perbaungan
# Processing Record 42 of Set 11 | linhares
# Processing Record 43 of Set 11 | vanavara
# Processing Record 44 of Set 11 | mutsu
# Processing Record 45 of Set 11 | tabora
# Processing Record 46 of Set 11 | verkh-suetka
# Processing Record 47 of Set 11 | idil
# Processing Record 48 of Set 11 | itaperucu
# Processing Record 49 of Set 11 | benguela
# Processing Record 50 of Set 11 | balboa
# Processing Record 1 of Set 12 | teya
# Processing Record 2 of Set 12 | staryy nadym
# Processing Record 3 of Set 12 | vasterhaninge
# Processing Record 4 of Set 12 | belaya gora
# Processing Record 5 of Set 12 | udayagiri
# Processing Record 6 of Set 12 | mackay
# Processing Record 7 of Set 12 | the valley
# Processing Record 8 of Set 12 | san juan
# Processing Record 9 of Set 12 | westport
# Processing Record 10 of Set 12 | olesnica
# Processing Record 11 of Set 12 | khasan
# Processing Record 12 of Set 12 | ambilobe
# Processing Record 13 of Set 12 | wajima
# Processing Record 14 of Set 12 | mamallapuram
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | zhigansk
# Processing Record 17 of Set 12 | msanga
# Processing Record 18 of Set 12 | mariinsk
# Processing Record 19 of Set 12 | gorahun
# Processing Record 20 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 12 | mehamn
# Processing Record 22 of Set 12 | santa rosa
# Processing Record 23 of Set 12 | macenta
# Processing Record 24 of Set 12 | eydhafushi
# Processing Record 25 of Set 12 | abay
# Processing Record 26 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 27 of Set 12 | tatvan
# Processing Record 28 of Set 12 | kokkola
# Processing Record 29 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 12 | krasnyy yar
# Processing Record 31 of Set 12 | ibra
# Processing Record 32 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 12 | grasse
# Processing Record 34 of Set 12 | changli
# Processing Record 35 of Set 12 | puerto leguizamo
# Processing Record 36 of Set 12 | neiafu
# Processing Record 37 of Set 12 | altay
# Processing Record 38 of Set 12 | nizhniy kuranakh
# Processing Record 39 of Set 12 | shimoda
# Processing Record 40 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 41 of Set 12 | otavi
# Processing Record 42 of Set 12 | tuxpan
# Processing Record 43 of Set 12 | priupskiy
# Processing Record 44 of Set 12 | pilikwe
# Processing Record 45 of Set 12 | itoman
# Processing Record 46 of Set 12 | telimele
# Processing Record 47 of Set 12 | hanzhong
# Processing Record 48 of Set 12 | mezen
# Processing Record 49 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 50 of Set 12 | hauterive
# Processing Record 1 of Set 13 | kinkala
# Processing Record 2 of Set 13 | santa cruz
# Processing Record 3 of Set 13 | abong mbang
# Processing Record 4 of Set 13 | meulaboh
# Processing Record 5 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 13 | yaring
# Processing Record 7 of Set 13 | tabuk
# Processing Record 8 of Set 13 | katha
# City not found. Skipping...
# Processing Record 9 of Set 13 | asyut
# Processing Record 10 of Set 13 | zhangjiakou
# Processing Record 11 of Set 13 | oswego
# Processing Record 12 of Set 13 | honningsvag
# Processing Record 13 of Set 13 | waddan
# Processing Record 14 of Set 13 | viedma
# Processing Record 15 of Set 13 | puerto cabezas
# Processing Record 16 of Set 13 | port macquarie
# Processing Record 17 of Set 13 | columbus
# Processing Record 18 of Set 13 | tshane
# Processing Record 19 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 20 of Set 13 | port-gentil
# Processing Record 21 of Set 13 | faanui
# Processing Record 22 of Set 13 | imbituba
# Processing Record 23 of Set 13 | moose factory
# Processing Record 24 of Set 13 | matsanga
# City not found. Skipping...
# Processing Record 25 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 26 of Set 13 | morondava
# Processing Record 27 of Set 13 | esso
# Processing Record 28 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 13 | valence
# Processing Record 30 of Set 13 | bursol
# City not found. Skipping...
# Processing Record 31 of Set 13 | rehoboth
# Processing Record 32 of Set 13 | great yarmouth
# Processing Record 33 of Set 13 | leh
# Processing Record 34 of Set 13 | kahama
# Processing Record 35 of Set 13 | amuntai
# Processing Record 36 of Set 13 | luena
# Processing Record 37 of Set 13 | barcelona
# Processing Record 38 of Set 13 | weihai
# Processing Record 39 of Set 13 | tezu
# Processing Record 40 of Set 13 | valley city
# Processing Record 41 of Set 13 | praya
# Processing Record 42 of Set 13 | guanica
# Processing Record 43 of Set 13 | san antero
# Processing Record 44 of Set 13 | atar
# Processing Record 45 of Set 13 | sri aman
# Processing Record 46 of Set 13 | tazovskiy
# Processing Record 47 of Set 13 | jasper
# Processing Record 48 of Set 13 | quang ngai
# Processing Record 49 of Set 13 | lakes entrance
# Processing Record 50 of Set 13 | kushiro
# Processing Record 1 of Set 14 | west odessa
# Processing Record 2 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 14 | chapais
# Processing Record 4 of Set 14 | dickinson
# Processing Record 5 of Set 14 | khanewal
# Processing Record 6 of Set 14 | dongying
# Processing Record 7 of Set 14 | walvis bay
# Processing Record 8 of Set 14 | novyy svit
# Processing Record 9 of Set 14 | carballo
# Processing Record 10 of Set 14 | salisbury
# Processing Record 11 of Set 14 | acapulco
# Processing Record 12 of Set 14 | camapua
# Processing Record 13 of Set 14 | lubango
# Processing Record 14 of Set 14 | bend
# Processing Record 15 of Set 14 | urucurituba
# Processing Record 16 of Set 14 | avera
# Processing Record 17 of Set 14 | altamont
# Processing Record 18 of Set 14 | rio gallegos
# Processing Record 19 of Set 14 | pedana
# Processing Record 20 of Set 14 | ola
# Processing Record 21 of Set 14 | la palma
# Processing Record 22 of Set 14 | dalmau
# Processing Record 23 of Set 14 | yecuatla
# Processing Record 24 of Set 14 | riohacha
# Processing Record 25 of Set 14 | manono
# Processing Record 26 of Set 14 | porto novo
# Processing Record 27 of Set 14 | peniche
# Processing Record 28 of Set 14 | baglung
# Processing Record 29 of Set 14 | takoradi
# Processing Record 30 of Set 14 | totness
# Processing Record 31 of Set 14 | kayerkan
# Processing Record 32 of Set 14 | namibe
# Processing Record 33 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 14 | caiaponia
# Processing Record 35 of Set 14 | madimba
# Processing Record 36 of Set 14 | neryungri
# Processing Record 37 of Set 14 | hanna
# Processing Record 38 of Set 14 | storm lake
# Processing Record 39 of Set 14 | frontignan
# Processing Record 40 of Set 14 | baherden
# Processing Record 41 of Set 14 | maridi
# Processing Record 42 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 14 | riviere-au-renard
# Processing Record 44 of Set 14 | maldonado
# Processing Record 45 of Set 14 | port augusta
# Processing Record 46 of Set 14 | luderitz
# Processing Record 47 of Set 14 | qaqortoq
# Processing Record 48 of Set 14 | sundumbili
# Processing Record 49 of Set 14 | warri
# Processing Record 50 of Set 14 | ust-ilimsk
# Processing Record 1 of Set 15 | sompeta
# Processing Record 2 of Set 15 | zharkent
# Processing Record 3 of Set 15 | aban
# Processing Record 4 of Set 15 | koroni
# Processing Record 5 of Set 15 | valleyview
# Processing Record 6 of Set 15 | palana
# Processing Record 7 of Set 15 | eyl
# Processing Record 8 of Set 15 | ternate
# Processing Record 9 of Set 15 | sola
# Processing Record 10 of Set 15 | salinas
# Processing Record 11 of Set 15 | yagodnoye
# Processing Record 12 of Set 15 | nayoro
# Processing Record 13 of Set 15 | vanimo
# Processing Record 14 of Set 15 | fort nelson
# Processing Record 15 of Set 15 | north platte
# Processing Record 16 of Set 15 | thanh hoa
# Processing Record 17 of Set 15 | pierre
# Processing Record 18 of Set 15 | roebourne
# Processing Record 19 of Set 15 | launceston
# Processing Record 20 of Set 15 | rosarito
# Processing Record 21 of Set 15 | santa cruz del sur
# Processing Record 22 of Set 15 | cape elizabeth
# City not found. Skipping...
# Processing Record 23 of Set 15 | bone
# Processing Record 24 of Set 15 | alugan
# Processing Record 25 of Set 15 | kieta
# Processing Record 26 of Set 15 | cap malheureux
# Processing Record 27 of Set 15 | vardo
# Processing Record 28 of Set 15 | karratha
# Processing Record 29 of Set 15 | diglur
# Processing Record 30 of Set 15 | ketchikan
# Processing Record 31 of Set 15 | licheng
# Processing Record 32 of Set 15 | dukat
# Processing Record 33 of Set 15 | matara
# Processing Record 34 of Set 15 | tessalit
# Processing Record 35 of Set 15 | buren
# Processing Record 36 of Set 15 | yefremov
# Processing Record 37 of Set 15 | iranshahr
# Processing Record 38 of Set 15 | amga
# Processing Record 39 of Set 15 | alghero
# Processing Record 40 of Set 15 | banska bystrica
# Processing Record 41 of Set 15 | muromtsevo
# Processing Record 42 of Set 15 | yialos
# City not found. Skipping...
# Processing Record 43 of Set 15 | buxton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Add the data to a new DataFrame.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_city_data_df = pd.DataFrame(city_data)
new_city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata      AR -38.0023  -57.5575     61.88        85          40
# 1    San Quintin      MX  30.4833 -115.9500     58.35        87           0
# 2           Lebu      CL -37.6167  -73.6500     55.24        85           1
# 3        Iqaluit      CA  63.7506  -68.5145     10.13        72          90
# 4          Metro      ID  -5.1131  105.3067     85.23        68         100
# 5         Albany      US  42.6001  -73.9662     43.66        61         100
# 6      Mahebourg      MU -20.4081   57.7000     82.69        65          40
# 7   Kruisfontein      ZA -34.0033   24.7314     65.88        84          87
# 8       Thompson      CA  55.7435  -97.8558    -23.64        76           1
# 9   Punta Arenas      CL -53.1500  -70.9167     43.23        75          99
#
#    Wind Speed Weather Description
# 0        1.99    scattered clouds
# 1        8.12           clear sky
# 2        1.88           clear sky
# 3       13.00     overcast clouds
# 4        8.81       moderate rain
# 5        3.00     overcast clouds
# 6       13.80    scattered clouds
# 7       19.04     overcast clouds
# 8        8.05           clear sky
# 9        4.85     overcast clouds

# %% [markdown]
# ### Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
